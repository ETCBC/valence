# %% [markdown]
# <img align="right" src="images/dans-small.png"/>
# <img align="right" src="images/tf-small.png"/>
# <img align="right" src="images/etcbc.png"/>
#
#
# # Senses
#
# We visualize the distribution of *sense labels* of verb occurrences, where verb occurrences select senses that depend on the number and nature of key constituents in their context.
#
# The verbal sense data has been computed in the
# [flowchart notebook](flowchart.ipynb).
#
# In this notebook we show how to make use of that data.
#
# For more information about the flowchart computations and the results,
# read the [wiki](https://github.com/ETCBC/valence/wiki/Workflows).
#
# Or go straight to the [legend](https://github.com/ETCBC/valence/wiki/Legend) of the sense labels.

# %% [markdown]
# # Results
# We have drawn the results of this notebook to the top.

# %%
# Run this cell as the last one.
for lex in frequentVerbLexs:  # noqa F821
    getSenseDistr(lex)  # noqa F821
# Out:
# 5277
# 3533
# 2468
# 1973
# 1912
# 1383
# 1106
# 1024
# 38
# 785

# %% [markdown]
# [legend](https://github.com/ETCBC/valence/wiki/Legend)

# %% [markdown]
# ## Authors
#
# [Janet Dyk and Dirk Roorda](https://github.com/ETCBC/valence/wiki/Authors)
#
# Last modified 2017-09-14.

# %% [markdown]
# ## Data
# We carry out the valence project against the Hebrew Text Database of the BHSA, version `4b`.
# See the description of the [sources](https://github.com/ETCBC/valence/wiki/Sources).

# %%
import collections  # noqa E402
from IPython.display import display  # noqa E402

import matplotlib.pyplot as plt  # noqa E402

# %matplotlib inline

from tf.fabric import Fabric  # noqa E402

# %%
locations = "~/github/etcbc"
sources = ["bhsa", "valence"]
version = "2017"

# %%
modules = ["{}/tf/{}".format(s, version) for s in sources]
TF = Fabric(locations=locations, modules=modules)
# Out:
# This is Text-Fabric 3.0.9
# Api reference : https://github.com/Dans-labs/text-fabric/wiki/Api
# Tutorial      : https://github.com/Dans-labs/text-fabric/blob/master/docs/tutorial.ipynb
# Example data  : https://github.com/Dans-labs/text-fabric-data
#
# 124 features found and 0 ignored

# %%
api = TF.load(
    """
    sp vs
    lex gloss
    freq_lex
    predication sense
    mother
"""
)
api.makeAvailableIn(globals())
# Out:
#   0.00s loading features ...
#    |     0.12s B sp                   from /Users/dirk/github/etcbc/bhsa/tf/2017
#    |     0.12s B vs                   from /Users/dirk/github/etcbc/bhsa/tf/2017
#    |     0.12s B lex                  from /Users/dirk/github/etcbc/bhsa/tf/2017
#    |     0.00s B gloss                from /Users/dirk/github/etcbc/bhsa/tf/2017
#    |     0.09s B freq_lex             from /Users/dirk/github/etcbc/bhsa/tf/2017
#    |     0.06s B predication          from /Users/dirk/github/etcbc/valence/tf/2017
#    |     0.02s B sense                from /Users/dirk/github/etcbc/valence/tf/2017
#    |     0.20s B mother               from /Users/dirk/github/etcbc/bhsa/tf/2017
#    |     0.00s Feature overview: 118 for nodes; 5 for edges; 1 configs; 7 computed
#   5.20s All features loaded/computed - for details use loadLog()

# %% [markdown]
# # Overall sense label distribution
#
# Let's start with a distribution of the sense labels themselves.
#
# First collect the data. Here are the sense labels.

# %%
senseLabels = sorted({F.sense.v(v) for v in F.otype.s("word")} - {None})
print(" ".join(senseLabels))
# Out:
# -- -b -c -i -p c. d- db dc di dp i. k. l. n.

# %% [markdown]
# We adjust the order of the sense labels manually, for clarity of presentation later on.

# %%
senseLabels = "-- -i -b -p -c d- di db dp dc n. l. k. i. c.".split()
print(" ".join(senseLabels))
# Out:
# -- -i -b -p -c d- di db dp dc n. l. k. i. c.

# %% [markdown]
# Now we count how many times the labels occur.

# %%
senseCount = collections.Counter()
noSense = []
isPredicate = {"regular", "copula"}

for v in F.sp.s("verb"):
    sense = F.sense.v(v)
    if sense is None:
        # skip words that are not verbs in the qal
        if F.vs.v(v) != "qal":
            continue
        # skip verbs in a phrase that is not a verb phrase, e.g. some participles
        # the criterion here is whether the value of feature `predication` is non trivial
        p = L.u(v, "phrase")
        if F.predication.v(p) not in isPredicate:
            continue
        noSense.append(v)
        continue
    senseCount[sense] += 1
TF.info("Counted {} senses".format(sum(senseCount.values())))
if noSense:
    TF.error("{} verb occurrences do not have a sense".format(len(noSense)))
    for v in noSense[0:10]:
        print(
            "{:<20} word {:>6} phrase {:>6} = {:<5}".format(
                "{} {}:{}".format(*T.sectionFromNode(v)),
                v,
                L.u(v, "phrase")[0],
                F.lex.v(v),
            )
        )
else:
    TF.info("All relevant verbs have been assigned a sense")
# Out:
#     15s Counted 47385 senses
#     15s All relevant verbs have been assigned a sense

# %% [markdown]
# Show the sense counts.

# %%
x = range(len(senseLabels))
s = [senseCount[sl] for sl in senseLabels]
s
# Out:
# [18005, 2870, 66, 6188, 4243, 9995, 889, 61, 1851, 1071, 531, 875, 54, 629, 57]

# %% [markdown]
# Plot a chart with overall sense counts.

# %%
fig = plt.figure()
plt.bar(x, s, tick_label=senseLabels, align="center")
plt.title("verb sense labels")

# %% [markdown]
# [legend](https://github.com/ETCBC/valence/wiki/Legend)

# %% [markdown]
# # Sense label distribution per verb
#
# We show the sense label distribution for the most frequent verbs.
#
# First we need a function that plots a distribution, given a verb.
# The verb is given by its lexeme.

# %%
x = range(len(senseLabels))


def getSenseDistr(lex):
    occurrences = [
        v for v in F.otype.s("word") if F.sense.v(v) and F.lex.v(v).rstrip("[=]") == lex
    ]
    print(len(occurrences))
    gloss = ", ".join(sorted({F.gloss.v(L.u(v, otype="lex")[0]) for v in occurrences}))
    senseCount = collections.Counter()
    for v in occurrences:
        sense = F.sense.v(v)
        senseCount[sense] += 1
    s = [senseCount[sl] for sl in senseLabels]
    plt.figure()
    plt.bar(x, s, tick_label=senseLabels, align="center")
    plt.title("sense of {} = {}".format(lex, gloss))

# %%
getSenseDistr(">MR")
# Out:
# 5277

# %% [markdown]
# [legend](https://github.com/ETCBC/valence/wiki/Legend)

# %%
getSenseDistr("DBR")
# Out:
# 38

# %% [markdown]
# [legend](https://github.com/ETCBC/valence/wiki/Legend)

# %% [markdown]
# # Sense label distribution frequent verbs
#
# We produce the sense label distributions for the 10 most frequent verbs.

# %%
frequentVerbNodes = sorted(
    (v for v in F.otype.s("word") if F.sp.v(v) == "verb" and F.vs.v(v) == "qal"),
    key=lambda v: -F.freq_lex.v(v),
)
len(frequentVerbNodes)
# Out:
# 50205

# %%
frequentVerbLexSet = set()
frequentVerbLexs = []
limit = 10
for v in frequentVerbNodes:
    if len(frequentVerbLexs) == 10:
        break
    lex = F.lex.v(v).rstrip("[=]")
    if lex in frequentVerbLexSet:
        continue
    frequentVerbLexSet.add(lex)
    frequentVerbLexs.append(lex)
frequentVerbLexs
# Out:
# ['>MR', 'HJH', '<FH', 'BW>', 'NTN', 'HLK', 'R>H', 'CM<', 'DBR', 'JCB']

# %% [markdown]
# ## What's the matter with `DBR`?
#
# `DBR` is a frequent verb, why do we see so few sense assignments?
# That's easy: we do only the `qal` stems, and `DBR` is strong in `piel`s and weak in `qal`s:

# %%
dbr = [v for v in F.sp.s("verb") if F.lex.v(v) == "DBR["]
dbrByStem = collections.Counter()
for v in dbr:
    dbrByStem[F.vs.v(v)] += 1

print(
    """
Frequency of the verb DBR: {:>4}
# Qal forms:               {:>4}
# Piel forms:              {:>4}
""".format(
        F.freq_lex.v(dbr[0]),
        dbrByStem["qal"],
        dbrByStem["piel"],
    )
)
# Out:
# Frequency of the verb DBR: 1138
# # Qal forms:                 41
# # Piel forms:              1089

# %% [markdown]
# # What's the matter with `>MR`?
# *to speak* is a transitive verb, you would expect lots of occurrences with a direct object, so senses
# `d-`, `di`, `db`, `dp`, `dc`.
# Instead, we see an overwhelming number of `--`.
# Why is that?
#
# In many cases, this verbs introduces direct speech.
# The direct speech could be regarded as the direct object of `>MR` in those cases.
# But the creators of the database have encoded the direct speech as separate sentences, hence our algorithm does not
# detect these kinds of direct objects.
#
# Let us have a look at a specific case, the clause starting with word 35.

# %%
wn = 35
cn = L.u(wn, "clause")[0]
can = L.u(wn, "clause_atom")[0]
sn = L.u(wn, "sentence")[0]
vn = L.u(wn, "verse")[0]
directSpeech = T.text(L.d(cn, "word"))
sentence = T.text(L.d(sn, "word"))
wholeVerse = T.text(L.d(vn, "word"))
print(
    "Consider clause {} in sentence {} in verse {}".format(
        directSpeech, sentence, wholeVerse
    )
)
# Out:
# Consider clause יְהִ֣י אֹ֑ור  in sentence יְהִ֣י אֹ֑ור  in verse וַיֹּ֥אמֶר אֱלֹהִ֖ים יְהִ֣י אֹ֑ור וַֽיְהִי־אֹֽור׃

# %% [markdown]
# It might be handy to have a look at
# [this verse on SHEBANQ](https://shebanq.ancient-data.org/hebrew/text?qactive=hlcustom&qsel_one=white&qpub=x&qget=v&wactive=hlcustom&wsel_one=black&wpub=x&wget=v&nactive=hlcustom&nsel_one=black&npub=x&nget=v&chapter=1&lang=en&book=Genesis&qw=n&tr=hb&tp=txt_tb1&iid=Mnx2YWxlbmNl&verse=3&version=4b&mr=m&page=2&c_q1510=turquoise&c_w1BRAv=yellow&wd4_statfl=v&ph_arela=v&wd4_statrl=v&sn_an=x&cl=v&wd1_lang=x&wd1_subpos=x&wd2_person=v&sp_rela=v&wd1_pdp=x&sn_n=v&wd3_uvf=x&ph_fun=v&wd1_nmtp=x&gl=x&sp_n=v&pt=x&ph_an=v&ph_typ=x&cl_typ=x&tt=x&wd4_statro=x&wd3_vbs=x&wd1=v&tl=x&wd3=x&wd4=x&wd2_gender=v&ph=x&wd3_vbe=v&wd1_pos=x&ph_det=v&ph_rela=x&wd4_statfo=x&tl_tlv=x&wd2_stem=v&wd2_state=v&ht=v&ph_n=v&tl_tlc=x&cl_tab=x&wd3_nme=x&hl=x&cl_par=x&cl_an=x&cl_n=v&wd3_prs=v&wd3_pfm=x&sp=x&cl_code=x&ht_hk=x&wd2=x&hl_hlc=x&cl_rela=x&wd2_gnumber=v&wd2_tense=v&cl_txt=x&wd1_n=v&sn=v&ht_ht=v&hl_hlv=v&pref=alt).
# After loading the page, click on the verse number 3 to see it with some underlying data in view, in this case the word, clause and sentence numbers.
#
# The question is now, is there a link from this clause to the preceding וַיֹּ֥אמֶר ?
#
# Let's ask for the mother of this clause, or its enclosing sentence.

# %%
print(
    """
mother of clause_atom: {}
mother of clause:      {}
mother of sentence:    {}
""".format(
        E.mother.f(can),
        E.mother.f(cn),
        E.mother.f(sn),
    )
)
# Out:
# mother of clause_atom: (515658,)
# mother of clause:      ()
# mother of sentence:    ()

# %% [markdown]
# Ah, the `clause_atom` has a mother link. Let's see where it leads.

# %%
mother = E.mother.f(can)[0]
print(
    """
Mother of clause_atom {} is a node {} of type {}
{}
""".format(
        can, mother, F.otype.v(mother), T.text(L.d(mother, "word"))
    )
)
# Out:
# Mother of clause_atom 515659 is a node 515658 of type clause_atom
# וַיֹּ֥אמֶר אֱלֹהִ֖ים

# %% [markdown]
# So it is a `clause_atom` to `clause_atom` link. Hm...

# %%
verbsWithDaughters = []
caWithDaughters = []

for v in F.sp.s("verb"):
    if F.vs.v(v) != "qal":
        continue
    p = L.u(v, "phrase")[0]
    if F.predication.v(p) not in isPredicate:
        continue
    ca = L.u(v, "clause_atom")[0]
    daughters = E.mother.t(ca)
    if len(daughters) == 0:
        continue
    verbsWithDaughters.append(v)
    caWithDaughters.append(ca)
print(
    "{} occurences of {} verbs in clause atoms with daughters".format(
        len(verbsWithDaughters),
        len({F.lex.v(v) for v in verbsWithDaughters}),
    )
)
# Out:
# 31178 occurences of 929 verbs in clause atoms with daughters

# %%
for ca in caWithDaughters[0:10]:
    print(
        "\n{:<15} mother {}".format(
            "{} {}:{}".format(*T.sectionFromNode(ca)),
            T.text(L.d(ca, "word")).rstrip("\n"),
        )
    )
    for da in E.mother.t(ca):
        print(
            "\t{:<15} daughter {}".format(
                "{} {}:{}".format(*T.sectionFromNode(da)),
                T.text(L.d(da, "word")).rstrip("\n"),
            )
        )
# Out:
# Genesis 1:1     mother בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖יִם וְאֵ֥ת הָאָֽרֶץ׃
# 	Genesis 1:2     daughter וְהָאָ֗רֶץ הָיְתָ֥ה תֹ֨הוּ֙ וָבֹ֔הוּ
# 	Genesis 1:3     daughter וַיֹּ֥אמֶר אֱלֹהִ֖ים
#
# Genesis 1:2     mother וְהָאָ֗רֶץ הָיְתָ֥ה תֹ֨הוּ֙ וָבֹ֔הוּ
# 	Genesis 1:2     daughter וְחֹ֖שֶׁךְ עַל־פְּנֵ֣י תְהֹ֑ום
#
# Genesis 1:3     mother וַיֹּ֥אמֶר אֱלֹהִ֖ים
# 	Genesis 1:3     daughter יְהִ֣י אֹ֑ור
# 	Genesis 1:3     daughter וַֽיְהִי־אֹֽור׃
# 	Genesis 1:4     daughter וַיַּ֧רְא אֱלֹהִ֛ים אֶת־הָאֹ֖ור
# 	Genesis 1:6     daughter וַיֹּ֣אמֶר אֱלֹהִ֔ים
#
# Genesis 1:4     mother וַיַּ֧רְא אֱלֹהִ֛ים אֶת־הָאֹ֖ור
# 	Genesis 1:4     daughter כִּי־טֹ֑וב
# 	Genesis 1:4     daughter וַיַּבְדֵּ֣ל אֱלֹהִ֔ים בֵּ֥ין הָאֹ֖ור וּבֵ֥ין הַחֹֽשֶׁךְ׃
#
# Genesis 1:5     mother וַיִּקְרָ֨א אֱלֹהִ֤ים׀ לָאֹור֙ יֹ֔ום
# 	Genesis 1:5     daughter וְלַחֹ֖שֶׁךְ קָ֣רָא לָ֑יְלָה
# 	Genesis 1:5     daughter וַֽיְהִי־עֶ֥רֶב
#
# Genesis 1:5     mother וַֽיְהִי־עֶ֥רֶב
# 	Genesis 1:5     daughter וַֽיְהִי־בֹ֖קֶר
#
# Genesis 1:5     mother וַֽיְהִי־בֹ֖קֶר
# 	Genesis 1:5     daughter יֹ֥ום אֶחָֽד׃ פ
#
# Genesis 1:6     mother וַיֹּ֣אמֶר אֱלֹהִ֔ים
# 	Genesis 1:6     daughter יְהִ֥י רָקִ֖יעַ בְּתֹ֣וךְ הַמָּ֑יִם
# 	Genesis 1:7     daughter וַיַּ֣עַשׂ אֱלֹהִים֮ אֶת־הָרָקִיעַ֒
# 	Genesis 1:9     daughter וַיֹּ֣אמֶר אֱלֹהִ֗ים
#
# Genesis 1:6     mother יְהִ֥י רָקִ֖יעַ בְּתֹ֣וךְ הַמָּ֑יִם
# 	Genesis 1:6     daughter וִיהִ֣י מַבְדִּ֔יל בֵּ֥ין מַ֖יִם לָמָֽיִם׃
#
# Genesis 1:7     mother וַיַּ֣עַשׂ אֱלֹהִים֮ אֶת־הָרָקִיעַ֒
# 	Genesis 1:7     daughter וַיַּבְדֵּ֗ל בֵּ֤ין הַמַּ֨יִם֙
# 	Genesis 1:8     daughter וַיִּקְרָ֧א אֱלֹהִ֛ים לָֽרָקִ֖יעַ שָׁמָ֑יִם

# %% [markdown]
# Without additional information, the presence of a mother link is not sufficient to draw in clause atoms as additional complements to a verb.
